# %% [markdown]
# #Lab 0: Colab Practice - Victoria Ama Nyonator

# %%
# Cell 1: Verify environment
import sys
import subprocess
from wordcloud import WordCloud
import matplotlib.pyplot as plt

print(f"Python version: {sys.version}")
print(f"Running on Colab: {'google.colab' in sys.modules}\n")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Running on Colab: True

# %%
# Cell 2: Check GPU status
gpu_info = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
if gpu_info.returncode == 0:
    print("GPU Available:")
    print(gpu_info.stdout[:400]) # Prints the top section of the GPU specs
else:
    print("No GPU detected - enable in Runtime > Change runtime type")
# Out:
# GPU Available:
# Fri Jun  5 19:51:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |

# %%
# Cell 3: Create an AI Word Cloud
text = "Artificial Intelligence Machine Learning Deep Learning Neural Networks Python Data Science"
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('AI Course Word Cloud')
plt.show()
